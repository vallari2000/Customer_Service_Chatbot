# %%
import nltk

# %%
import pickle

# %%
from nltk.stem import WordNetLemmatizer
import json
lem = WordNetLemmatizer()

# %%
import random
import numpy as np

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD

# %%
words =[]
documents= []
classes = []
ignore_words = ['!','?',':',';','.',',','-']

# %%
intents = open('intents.json').read()
images = open('images.json').read()
suggestions = open('suggestions.json').read()

# %%
intents = json.loads(intents)

# %%
images = json.loads(images)

# %%
suggestions = json.loads(suggestions)

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        documents.append((w,intent['tag']))
        
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
words = [lem.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
classes = sorted(list(set(classes)))

# %%
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# %%
training=[]

output_empty = [0]*len(classes)

for doc in documents:
    
    bag =[]
    
    pattern_words = doc[0] # list of tokenized words for each doc
    
    pattern_words = [lem.lemmatize(w.lower()) for w in pattern_words]
    
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] =1
    training.append([bag , output_row])

random.shuffle(training)
training  = np.array(training)
train_x = list(training[:,0])
train_y = list(training[:,1])

# %%
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu')) #input layer
model.add(Dropout(0.5))
model.add(Dense(64,activation='relu')) #hidden layer with 64 neurons
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]),activation='softmax')) #output layer number of neurons=intent

sgd = SGD(lr = 0.01, decay = 1e-6, momentum=0.9, nesterov=True) # learning rate = 0.01 
model.compile(loss='categorical_crossentropy', optimizer = sgd, metrics = ['accuracy'])

#fitting and saving the model

hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)

model.save('chatbot_model.h5', hist)
# Out:
# Epoch 1/200
# 27/27 [==============================] - 0s 2ms/step - loss: 3.9104 - accuracy: 0.0224
# Epoch 2/200
# 27/27 [==============================] - 0s 2ms/step - loss: 3.8049 - accuracy: 0.0672
# Epoch 3/200
# 27/27 [==============================] - 0s 2ms/step - loss: 3.7255 - accuracy: 0.0896
# Epoch 4/200
# 27/27 [==============================] - 0s 2ms/step - loss: 3.6643 - accuracy: 0.1045
# Epoch 5/200
# 27/27 [==============================] - 0s 2ms/step - loss: 3.5104 - accuracy: 0.1269
# Epoch 6/200
# 27/27 [==============================] - 0s 2ms/step - loss: 3.3940 - accuracy: 0.1642
# Epoch 7/200
# 27/27 [==============================] - 0s 2ms/step - loss: 3.2560 - accuracy: 0.2090
# Epoch 8/200
# 27/27 [==============================] - 0s 2ms/step - loss: 3.1824 - accuracy: 0.2090
# Epoch 9/200
# 27/27 [==============================] - 0s 2ms/step - loss: 2.9247 - accuracy: 0.2463
# Epoch 10/200
# 27/27 [==============================] - 0s 3ms/step - loss: 2.8877 - accuracy: 0.2836
# Epoch 11/200
# 27/27 [==============================] - 0s 2ms/step - loss: 2.5847 - accuracy: 0.2910
# Epoch 12/200
# 27/27 [==============================] - 0s 1ms/step - loss: 2.5131 - accuracy: 0.3657
# Epoch 13/200
# 27/27 [==============================] - 0s 1ms/step - loss: 2.4002 - accuracy: 0.3731
# Epoch 14/200
# 27/27 [==============================] - 0s 1ms/step - loss: 2.2194 - accuracy: 0.4030
# Epoch 15/200
# 27/27 [==============================] - 0s 1ms/step - loss: 2.1231 - accuracy: 0.4701
# Epoch 16/200
# 27/27 [==============================] - 0s 1ms/step - loss: 2.0265 - accuracy: 0.4179
# Epoch 17/200
# 27/27 [==============================] - 0s 2ms/step - loss: 1.7712 - accuracy: 0.5224
# Epoch 18/200
# 27/27 [==============================] - 0s 2ms/step - loss: 1.8245 - accuracy: 0.5224
# Epoch 19/200
# 27/27 [==============================] - 0s 1ms/step - loss: 1.7766 - accuracy: 0.5373
# Epoch 20/200
# 27/27 [==============================] - 0s 1ms/step - loss: 1.7814 - accuracy: 0.5149
# Epoch 21/200
# 27/27 [==============================] - 0s 1ms/step - loss: 1.4677 - accuracy: 0.6045
# Epoch 22/200
# 27/27 [==============================] - 0s 1ms/step - loss: 1.4876 - accuracy: 0.5821
# Epoch 23/200
# 27/27 [==============================] - 0s 1ms/step - loss: 1.4068 - accuracy: 0.5970
# Epoch 24/200
# 27/27 [==============================] - 0s 1ms/step - loss: 1.3570 - accuracy: 0.6418
# Epoch 25/200
# 27/27 [==============================] - 0s 1ms/step - loss: 1.4096 - accuracy: 0.6194
# Epoch 26/200
# 27/27 [==============================] - 0s 1ms/step - loss: 1.2020 - accuracy: 0.6418
# Epoch 27/200
# 27/27 [==============================] - 0s 1ms/step - loss: 1.2108 - accuracy: 0.6418
# Epoch 28/200
# 27/27 [==============================] - 0s 1ms/step - loss: 1.0965 - accuracy: 0.6791
# Epoch 29/200
# 27/27 [==============================] - 0s 1ms/step - loss: 1.1247 - accuracy: 0.6567
# Epoch 30/200
# 27/27 [==============================] - 0s 1ms/step - loss: 1.0257 - accuracy: 0.7015
# Epoch 31/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.8718 - accuracy: 0.7463
# Epoch 32/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.8494 - accuracy: 0.7537
# Epoch 33/200
# 27/27 [==============================] - 0s 1ms/step - loss: 1.0288 - accuracy: 0.6940
# Epoch 34/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.9571 - accuracy: 0.7164
# Epoch 35/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.9348 - accuracy: 0.7388
# Epoch 36/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.8815 - accuracy: 0.7388
# Epoch 37/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.8356 - accuracy: 0.7239
# Epoch 38/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.7027 - accuracy: 0.8134
# Epoch 39/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.7373 - accuracy: 0.8060
# Epoch 40/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.8409 - accuracy: 0.7910
# Epoch 41/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6768 - accuracy: 0.8134
# Epoch 42/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6117 - accuracy: 0.8209
# Epoch 43/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6770 - accuracy: 0.8209
# Epoch 44/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4768 - accuracy: 0.8881
# Epoch 45/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6966 - accuracy: 0.7910
# Epoch 46/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.5787 - accuracy: 0.8284
# Epoch 47/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6821 - accuracy: 0.7836
# Epoch 48/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5571 - accuracy: 0.8134
# Epoch 49/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6256 - accuracy: 0.8134
# Epoch 50/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6749 - accuracy: 0.7836
# Epoch 51/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6326 - accuracy: 0.8209
# Epoch 52/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6381 - accuracy: 0.7985
# Epoch 53/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.5143 - accuracy: 0.8731
# Epoch 54/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4521 - accuracy: 0.8507
# Epoch 55/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6377 - accuracy: 0.8284
# Epoch 56/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5802 - accuracy: 0.8806
# Epoch 57/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4734 - accuracy: 0.8358
# Epoch 58/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4202 - accuracy: 0.8806
# Epoch 59/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4648 - accuracy: 0.8358
# Epoch 60/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4872 - accuracy: 0.8582
# Epoch 61/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4653 - accuracy: 0.8433
# Epoch 62/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4098 - accuracy: 0.8955
# Epoch 63/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5007 - accuracy: 0.8433
# Epoch 64/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4240 - accuracy: 0.8731
# Epoch 65/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3919 - accuracy: 0.8731
# Epoch 66/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6451 - accuracy: 0.7985
# Epoch 67/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4916 - accuracy: 0.8358
# Epoch 68/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3889 - accuracy: 0.8806
# Epoch 69/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3938 - accuracy: 0.8881
# Epoch 70/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2788 - accuracy: 0.9403
# Epoch 71/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.5345 - accuracy: 0.8433
# Epoch 72/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4259 - accuracy: 0.8507
# Epoch 73/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4227 - accuracy: 0.8881
# Epoch 74/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4074 - accuracy: 0.8358
# Epoch 75/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3996 - accuracy: 0.8806
# Epoch 76/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4396 - accuracy: 0.8657
# Epoch 77/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3631 - accuracy: 0.8731
# Epoch 78/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4140 - accuracy: 0.8582
# Epoch 79/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3971 - accuracy: 0.9030
# Epoch 80/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3003 - accuracy: 0.9104
# Epoch 81/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3215 - accuracy: 0.9179
# Epoch 82/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3568 - accuracy: 0.8955
# Epoch 83/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3596 - accuracy: 0.8881
# Epoch 84/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4804 - accuracy: 0.8433
# Epoch 85/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2712 - accuracy: 0.9104
# Epoch 86/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4907 - accuracy: 0.8657
# Epoch 87/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3366 - accuracy: 0.8881
# Epoch 88/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4541 - accuracy: 0.8582
# Epoch 89/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3604 - accuracy: 0.8955
# Epoch 90/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2532 - accuracy: 0.9403
# Epoch 91/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3731 - accuracy: 0.8881
# Epoch 92/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3667 - accuracy: 0.8806
# Epoch 93/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2147 - accuracy: 0.9328
# Epoch 94/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3266 - accuracy: 0.8955
# Epoch 95/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3985 - accuracy: 0.8806
# Epoch 96/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3330 - accuracy: 0.8881
# Epoch 97/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3033 - accuracy: 0.8955
# Epoch 98/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3480 - accuracy: 0.8657
# Epoch 99/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4197 - accuracy: 0.8731
# Epoch 100/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4837 - accuracy: 0.8433
# Epoch 101/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3740 - accuracy: 0.8955
# Epoch 102/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2336 - accuracy: 0.9179
# Epoch 103/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2945 - accuracy: 0.9104
# Epoch 104/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2629 - accuracy: 0.9104
# Epoch 105/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2308 - accuracy: 0.9254
# Epoch 106/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2987 - accuracy: 0.9104
# Epoch 107/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2673 - accuracy: 0.9104
# Epoch 108/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2844 - accuracy: 0.9254
# Epoch 109/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2404 - accuracy: 0.9403
# Epoch 110/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3562 - accuracy: 0.8731
# Epoch 111/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3178 - accuracy: 0.9254
# Epoch 112/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3013 - accuracy: 0.9104
# Epoch 113/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3507 - accuracy: 0.9104
# Epoch 114/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2962 - accuracy: 0.9179
# Epoch 115/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3480 - accuracy: 0.8881
# Epoch 116/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2487 - accuracy: 0.9328
# Epoch 117/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3238 - accuracy: 0.8881
# Epoch 118/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2376 - accuracy: 0.9254
# Epoch 119/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1906 - accuracy: 0.9403
# Epoch 120/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2616 - accuracy: 0.9328
# Epoch 121/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3247 - accuracy: 0.9030
# Epoch 122/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2976 - accuracy: 0.9179
# Epoch 123/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1605 - accuracy: 0.9552
# Epoch 124/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3902 - accuracy: 0.8657
# Epoch 125/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3399 - accuracy: 0.8507
# Epoch 126/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3308 - accuracy: 0.9254
# Epoch 127/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3516 - accuracy: 0.8881
# Epoch 128/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3004 - accuracy: 0.9254
# Epoch 129/200
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3952 - accuracy: 0.8507
# Epoch 130/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2579 - accuracy: 0.8881
# Epoch 131/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2270 - accuracy: 0.9104
# Epoch 132/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1956 - accuracy: 0.9403
# Epoch 133/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3175 - accuracy: 0.8881
# Epoch 134/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2222 - accuracy: 0.9030
# Epoch 135/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1939 - accuracy: 0.9328
# Epoch 136/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4037 - accuracy: 0.8731
# Epoch 137/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1487 - accuracy: 0.9478
# Epoch 138/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1708 - accuracy: 0.9403
# Epoch 139/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1543 - accuracy: 0.9403
# Epoch 140/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2381 - accuracy: 0.9179
# Epoch 141/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1772 - accuracy: 0.9478
# Epoch 142/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3244 - accuracy: 0.8582
# Epoch 143/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1677 - accuracy: 0.9552
# Epoch 144/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2408 - accuracy: 0.9403
# Epoch 145/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2980 - accuracy: 0.9254
# Epoch 146/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1756 - accuracy: 0.9403
# Epoch 147/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1897 - accuracy: 0.9328
# Epoch 148/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2137 - accuracy: 0.9254
# Epoch 149/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2512 - accuracy: 0.9328
# Epoch 150/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1920 - accuracy: 0.9478
# Epoch 151/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2783 - accuracy: 0.9030
# Epoch 152/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2109 - accuracy: 0.9328
# Epoch 153/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2599 - accuracy: 0.9030
# Epoch 154/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2171 - accuracy: 0.9254
# Epoch 155/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2589 - accuracy: 0.9478
# Epoch 156/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2055 - accuracy: 0.9254
# Epoch 157/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3690 - accuracy: 0.8731
# Epoch 158/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3307 - accuracy: 0.9030
# Epoch 159/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3298 - accuracy: 0.9179
# Epoch 160/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1984 - accuracy: 0.9328
# Epoch 161/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2146 - accuracy: 0.9179
# Epoch 162/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2737 - accuracy: 0.9254
# Epoch 163/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1779 - accuracy: 0.9179
# Epoch 164/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2115 - accuracy: 0.9030
# Epoch 165/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2063 - accuracy: 0.9403
# Epoch 166/200
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2068 - accuracy: 0.9552
# Epoch 167/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1499 - accuracy: 0.9701
# Epoch 168/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1842 - accuracy: 0.9478
# Epoch 169/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2688 - accuracy: 0.9179
# Epoch 170/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3215 - accuracy: 0.9030
# Epoch 171/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1884 - accuracy: 0.9552
# Epoch 172/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3125 - accuracy: 0.9179
# Epoch 173/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1833 - accuracy: 0.9552
# Epoch 174/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2341 - accuracy: 0.9179
# Epoch 175/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2241 - accuracy: 0.9179
# Epoch 176/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1898 - accuracy: 0.9478
# Epoch 177/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2073 - accuracy: 0.9254
# Epoch 178/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1710 - accuracy: 0.9328
# Epoch 179/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2449 - accuracy: 0.9104
# Epoch 180/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2296 - accuracy: 0.9328
# Epoch 181/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1687 - accuracy: 0.9254
# Epoch 182/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2573 - accuracy: 0.8955
# Epoch 183/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2646 - accuracy: 0.9179
# Epoch 184/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1725 - accuracy: 0.9552
# Epoch 185/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1703 - accuracy: 0.9627
# Epoch 186/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2503 - accuracy: 0.9478
# Epoch 187/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2115 - accuracy: 0.9328
# Epoch 188/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2440 - accuracy: 0.8955
# Epoch 189/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1800 - accuracy: 0.9478
# Epoch 190/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1721 - accuracy: 0.9254
# Epoch 191/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2481 - accuracy: 0.9254
# Epoch 192/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2457 - accuracy: 0.8806
# Epoch 193/200
# 27/27 [==============================] - ETA: 0s - loss: 0.5480 - accuracy: 0.80 - 0s 1ms/step - loss: 0.2521 - accuracy: 0.9254
# Epoch 194/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1654 - accuracy: 0.9403
# Epoch 195/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2551 - accuracy: 0.9328
# Epoch 196/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1889 - accuracy: 0.9328
# Epoch 197/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2179 - accuracy: 0.9179
# Epoch 198/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2403 - accuracy: 0.9030
# Epoch 199/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2571 - accuracy: 0.9328
# Epoch 200/200
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2288 - accuracy: 0.9328

# %%
from keras.models import load_model

# %%
model = load_model('chatbot_model.h5')

# %%
intents = json.loads(open('intents.json').read())

words = pickle.load(open('words.pkl','rb'))

classes = pickle.load(open('classes.pkl','rb'))

# %%
def cleanup_sent(sentence):
    sen_words =  nltk.word_tokenize(sentence)
    sen_words = [lem.lemmatize(word.lower()) for word in sen_words]
    return sen_words

# %%
def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sen_words = cleanup_sent(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words) 
    for s in sen_words:
        for i,w in enumerate(words):
            if w == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

# %%
def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    PROB_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>PROB_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

# %%
def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result
def getImage(ints, images_json):
    list_images = images_json['intents']
    tag = ints[0]['intent']
    for i in list_images:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            return result
    return ("-1")
def getSuggest(ints, sugg_json):
    tag = ints[0]['intent']
    list_sugg = sugg_json['intents']
    for i in list_sugg:
        if(i['tag']== tag):
            result = i['responses']
            return result
    return("-1")
def chatbot_response(text):
    ints = predict_class(text, model)
    res = getResponse(ints, intents)
    img = getImage(ints, images)
    sugg = getSuggest(ints,suggestions)
    answer=[]
    answer.append(res)
    if img!='-1':
        answer.append(img)
    else:
        answer.append("-1")
    if sugg!='-1':
        answer.append(sugg)
    else:
        answer.append("-1")
    return answer

# %%
import tkinter
from tkinter import *
from PIL import Image,ImageTk

# %%
def fb():
    window = Toplevel(base)
    window.title("Feedback")
    window.geometry("200x200")
    var='0'
    #var.set(0)
    r1 = Radiobutton(window, text='1 Star ', variable=var, value='1', background = "light blue",command=window.destroy,tristatevalue=0)
    r1.pack(side = TOP, ipady = 5) 
    r2 = Radiobutton(window, text='2 Stars', variable=var, value='2',background = "light blue", command=window.destroy,tristatevalue=0)
    r2.pack(side = TOP, ipady = 5) 
    r3 = Radiobutton(window, text='3 Stars', variable=var, value='3', background = "light blue",command=window.destroy,tristatevalue=0)
    r3.pack(side = TOP, ipady = 5) 
    r4 = Radiobutton(window, text='4 Stars', variable=var, value='4', background = "light blue",command=window.destroy,tristatevalue=0)
    r4.pack(side = TOP, ipady = 5) 
    r5= Radiobutton(window, text='5 Stars', variable=var, value='5', background = "light blue",command=window.destroy,tristatevalue=0)
    r5.pack(side = TOP, ipady = 5) 
    ChatLog.config(state = NORMAL)
        
    return var

# %%
def printfb(var):
    ChatLog.insert(END, "Jarvis:Thank you for your feedback!\n\n")
    ChatLog.config(state=DISABLED)
    ChatLog.yview(END)

# %%
global img

def send():
    
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)
    if msg != '':
        ChatLog.config(state = NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 14, 'bold' ))
        
        answer = chatbot_response(msg)
        res=answer[0]
        ChatLog.insert(END, "Jarvis: " + res + '\n\n')
        if answer[1]!='-1':
            ChatLog.insert(END, "Jarvis: ")
            result = answer[1]
            img=Image.open(result)
            img=img.resize((300,300),Image.ANTIALIAS)
            img=ImageTk.PhotoImage(img)
            ChatLog.image=img
            ChatLog.image_create(INSERT, image=img)
        if answer[2]!='-1':
            #for i in answer[2]:
            ChatLog.window_create(ChatLog.index("end"), window = Button(ChatLog, text=answer[2][0], width=50,height=2,bg='white',command=lambda:suggsend(answer[2][0])) ) 
            ChatLog.window_create(ChatLog.index("end"), window = Button(ChatLog, text=answer[2][1], width=50,height=2,bg='white',command=lambda:suggsend(answer[2][1])) )
            ChatLog.window_create(ChatLog.index("end"), window = Button(ChatLog, text=answer[2][2], width=50,height=2,bg='white',command=lambda:suggsend(answer[2][2])) )
            
        ChatLog.insert(END, "\n\n")
        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)
def suggsend(i):
    ChatLog.config(state = NORMAL)
    ChatLog.config(foreground="#442265", font=("Verdana", 16,'bold'))
    answer = chatbot_response(i)
    res=answer[0]
    ChatLog.insert(END, "Jarvis: " + res + '\n')
    
base = Tk()
base.title("Welcome to Customer Care")
base.geometry("700x500")
base.resizable(width=FALSE, height=FALSE)
    
ChatLog = Text(base, bd=0, bg="#FAF5A8", height="8", width="50", font=("Arial",16,'bold'))
        
ChatLog.config(state =  DISABLED)
    
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set
    
SendButton = Button(base, font=("Comic Sans MS",14,'bold'), text="SEND", width="12", height=5,
                    bd=0, bg="#3cd548", activebackground="#3c9d9b",fg='#ffffff',
                    command=send )
 
    #Create the box to enter message

EntryBox = Text(base, bd=0, bg="#FAF5A8",width="29", height="5", font=("Arial",14))
  
scrollbar.place(x=600,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=599)
EntryBox.place(x=6, y=401, height=70, width=350)
SendButton.place(x=370, y=410, height=50,width=150)
fbButton = Button(base, font=("Verdana",12,'bold'), text="Feedback", width="12", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
                    command=lambda:printfb(fb()))

fbButton.place(x=6, y=350, height=40) 
base.mainloop()
